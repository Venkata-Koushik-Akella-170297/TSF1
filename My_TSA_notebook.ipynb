# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# Useful in
#
# _**Economic outlook**_ - forecasting economic situations based on the previous income/expenditure of citizens
#
# _**Sales forecasting**_ - forecasting sales of a company based on the previous data trends
#
# _**Inventory planning**_ - plan stocking the inventory based on future demand for a product
#
# _**Workforce planning**_ - plan workforce based on the demand of a product by a particular company
#
# _**Weather prediction**_ - predict weather in future based on data trends from the past like temp, humidity, rainfall.
#
# this module will cover the following:
#
#     1. Defining the time series
#
#     2. Analysing a time-series dataset to identify patterns
#
#     3. Build various time series models to forecast
#
#     4. Evaluate the forecast using various error measures

# %% [markdown]
# There are two types of forecasting
# 1. **Qualitative Forecasting**
# 2. **Quantative Forecasting**

# %% [markdown]
# ![Screenshot%202023-07-03%20at%209.13.44%20PM.png](attachment:Screenshot%202023-07-03%20at%209.13.44%20PM.png)

# %% [markdown]
# **Time Series Data**: Any data that has a time component involved in it is termed as a time-series data. For example, the number of orders made on a food ordering app per day is an example of time-series data.
#
# **Time Series Analysis**: Performing analysis on a time-series data to find useful insights and patterns is termed as time series analysis. Let's take a food ordering app example again. The app might have the data for every day logged in per hour. They might notice that in this data, the number of orders is significantly higher in, say, the 1-2 PM time slot but is significantly lower in the 3-4 PM time slot. This information might be useful for them as they would then be able to estimate the number of delivery boys required at a particular time of the day. Hence, time series analysis is indispensable while working with any time series data.
#
# **Time Series Forecasting**: Time series forecasting is basically looking at the past data to make predictions into the future. Say that the food ordering app wants to predict the number of orders per day for the next month in order to plan the resources better. For this, they will look at tons of past data and use it in order to forecast accurately.

# %% [markdown]
# ![goal-plan-forecast.png](attachment:goal-plan-forecast.png)

# %% [markdown]
# **Goal**: A set of business objectives. For example, maximising revenue, maximising capital, etc.
#
# **Plan**: A set of actions that a business takes to achieve the goal. In order to come up with a good plan, they need a forecast.
#
# **Forecast**: Is the prediction of the future.

# %% [markdown]
# **Basic steps of Time series forecasting:**
#
# _1. Define the problem_
#
# _2. Collect the data_
#
# _3. Analyze the data_
#
# _4. Build and evaluate the forecast model_

# %% [markdown]
# **what to forecast?**
#
# 1. Quantity -  what is being forecast, price, sales?
# 2. Granularity - what is the granular level to which it is forecast? - store level, regional level etc,
#
# 3. Frequency - monthly, quarterly, yearly is the data forecast
#
# 4. Horizon -
#     1. Short term: operational stuff: scheduling machines, workforce etc,
#     2. Medium term: planning and target setting - how many to hire, revenue target setting
#     3. Long term: starting a new outlet, factory, etc

# %% [markdown]
# two approaches to analyze the time series data:
# 1. Bottom-up approach: start from granular level and increase to forecast monthly sales of a store and sum up to get the monthly sales of the entire region
# 2. Top-down approach: start from monthly sales data nation wide, breakdown to find the sales data of a particular store in a single day.

# %% [markdown]
# _some caveats associated with a time series forecasting. These caveats revolve around the steps you learnt about while defining the problem:_
#
# _**The Granularity Rule**_: The more aggregate your forecasts, the more accurate you are in your predictions simply because aggregated data has lesser variance and hence, lesser noise. As a thought experiment, suppose you work at ABC, an online entertainment streaming service, and you want to predict the number of views for a few newly launched TV show in Mumbai for the next one year. Now, would you be more accurate in your predictions if you predicted at the city-level or if you go at an area-level? Obviously, accurately predicting the views from each area might be difficult but when you sum up the number of views for each area and present your final predictions at a city-level, your predictions might be surprisingly accurate. This is because, for some areas, you might have predicted lower views than the actual whereas, for some, the number of predicted views might be higher. And when you sum all of these up, the noise and variance cancel each other out, leaving you with a good prediction. Hence, you should not make predictions at very granular levels.
#
# _**The Frequency Rule**_: This rule tells you to keep updating your forecasts regularly to capture any new information that comes in. Let's continue with the ABC, an online entertainment streaming service, an example where the problem is to predict the number of views for a newly launched TV show in Mumbai for the next year. Now, if you keep the frequency too low, you might not be able to capture accurately the new information coming in. For example, say, your frequency for updating the forecasts is 3 months. Now, due to the COVID-19 pandemic, the residents may be locked in their homes for around 2-3 months during which the number of views will significantly increase. Now, if the frequency of your forecast is only 3 months, you will not be able to capture the increase in views which may incur significant losses and lead to mismanagement.
#
# _**The Horizon Rule**_: When you have the horizon planned for a large number of months into the future, you are more likely to be accurate in the earlier months as compared to the later ones. Let's again go back to ABC, an online entertainment streaming service, example. Suppose that the online entertainment streaming service made a prediction for the number of views for the next 6 months in December 2019. Now, it may have been quite accurate for the first two months, but due to the unforeseen COVID-19 situation, the actual number of view in the next couple of months would have been significantly higher than predicted because of everyone staying at home. The farther ahead we go into the future, the more uncertain we are about the forecasts.

# %% [markdown]
# _three important characteristics that every time series data must exhibit in order for us to make a good forecast:_
#
# **Relevant**: The time-series data should be relevant for the set objective that we want to achieve.
#
# **Accurate**: The data should be accurate in terms of capturing the timestamps and capturing the observation correctly.
#
# **Long enough**: The data should be long enough to forecast. This is because it is important to identify all the patterns in the past and forecast which patterns repeat in the future.

# %% [markdown]
# _various types of data sources to get a time-series data:_
#
# **Private enterprise data**: E.g. financial information about the quarterly results of any private organisation.
#
# **Public data**: E.g. government publishes the economic indicators  such as GDP, consumer price index etc.
#
# **System/Sensor data**: E.g. Logs generated by the servers during their 24/7 working hours.

# %% [markdown]
# _few components associated with time series:_
#
# **Level**: This is the baseline of a time series. This gives the baseline to which we add the different other components.
#
# **Trend**: Over a longterm, this gives an indication of whether the time series moves lower or higher. For example, in the following Sensex graph you can clearly observe that with  time, the overall value is increasing i.e. this particular time series data has an increasing trend.
#
# ![Trend.png](attachment:Trend.png)

# %% [markdown]
# **Seasonality**: It is a pattern in a time-series data that repeats itself after a given period of time. For example, in the following graph 'Monthly sales data of company X', you can clearly observe that a fixed pattern is repeating every year. The simplest example to explain this could be, say, the sales of winter wear in India. In winter, during months like November-January, you would expect these sales to be very high whereas for the other months, the sales might be low. This shows a seasonality pattern and proves to be very useful when making forecasts.
#
# ![seasonality.png](attachment:seasonality.png)

# %% [markdown]
# **Cyclicity**: It is also a repeating pattern in data that repeats itself aperiodically. We don’t get into the more details of this component as it is out of the scope of this module.
#
# ![cyclicity.png](attachment:cyclicity.png)

# %% [markdown]
# **Noise**: Noise is the completely random fluctuation present in the data and we cannot use this component to forecast into the future. This is that component of the time series data that no one can explain and is completely random.
#
# ![noise.png](attachment:noise.png)

# %% [markdown]
# **NOTE: every time series data has level and noise. Trend, seasonality and cyclicity are not mandatorily present**

# %% [markdown]
# # Importing the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# import data
data = pd.read_csv('airline-passenger-traffic.csv', header=None)

# %%
data.head()
# Out:
#          0      1
# 0  1949-01  112.0
# 1  1949-02  118.0
# 2  1949-03  132.0
# 3  1949-04  129.0
# 4  1949-05  121.0

# %%
data.columns = ['Month', 'Passengers']
data['Month'] = pd.to_datetime(data['Month'], format='%Y-%m')
data = data.set_index('Month')

# %%
data.head()
# Out:
#             Passengers
# Month
# 1949-01-01       112.0
# 1949-02-01       118.0
# 1949-03-01       132.0
# 1949-04-01       129.0
# 1949-05-01       121.0

# %%
data.shape
# Out:
# (144, 1)

# %% [markdown]
# ## Time series analysis

# %% [markdown]
# ### Plot the time series data

# %%
data.plot(figsize=(13,5))
plt.legend(loc='best')
plt.title('Airline passenger traffic data')
plt.show(block=False)

# %% [markdown]
# Missing values could exist in any time-series data for multiple reasons, some of the reasons are listed below:
# 1. Previous observations data was not entered in the dataset
# 2. The data was not recorded as the event did not occur. For example, if sales did not happen on x date, the record entry of sales would be 0 on that particular date.

# %% [markdown]
# ## Various missing value treatment methods

# %% [markdown]
# _Imputation methods for missing values:_
#
# **Mean Imputation**: Imputing the missing values with the overall mean of the data
#
# ![Mean_imputation.png](attachment:Mean_imputation.png)

# %% [markdown]
# **Last observation carried forward**: We impute the missing values with its previous value in the data.
#
# ![Last_obs_carried_forward.png](attachment:Last_obs_carried_forward.png)

# %% [markdown]
# **Linear interpolation**: You draw a straight line joining the next and previous points of the missing values in the data.
#
# ![Linear_interpolation.png](attachment:Linear_interpolation.png)

# %% [markdown]
# **Seasonal + Linear interpolation**: This method is best applicable for the data with trend and seasonality. Here, the missing value is imputed with the average of the corresponding data point in the previous seasonal period and the next seasonal period of the missing value.
#
# ![Seasonal+linear.png](attachment:Seasonal+linear.png)

# %% [markdown]
# ## Missing value treatment for the passengers:

# %% [markdown]
# ### Mean inputation

# %%
data = data.assign(Passengers_Mean_Imputation=data.Passengers.fillna(data.Passengers.mean()))
data[['Passengers_Mean_Imputation']].plot(figsize = (13,4))
plt.legend(loc='best')
plt.title('Airline traffic data: Mean imputation')
plt.show(block=False)

# %%
data = data.assign(Passenger_linear_interpolation = data.Passengers.interpolate(method = 'linear'))
data['Passenger_linear_interpolation'].plot(figsize = (12,4))
plt.legend(loc = 'best')
plt.title('Airline passenger traffic: Linear interpolation')
plt.show(block=False)

# %% [markdown]
# from the above two methods, it is quiet evident that linear interpolation is giving good trend with imputation of missing values. hence we'll use linear interpolation in this regard

# %%
data['Passengers'] = data['Passenger_linear_interpolation']

# %% [markdown]
# ## Outlier detection:

# %% [markdown]
# **Extreme value analysis**: Remove the smallest and largest values in the dataset.
#
# ![Extreme_value_analysis.png](attachment:Extreme_value_analysis.png)

# %% [markdown]
# **Box Plot**: The points lying on either side of the whiskers are considered to be outliers as shown in the image. The length of these whiskers is subjective and can be defined by you according to the problem.
#
# ![Boxplot.png](attachment:Boxplot.png)

# %% [markdown]
# **Histogram**: Simply plotting a histogram can also reveal the outliers - basically the extreme values with low frequencies visible in the plot.
#
# ![Histogram.png](attachment:Histogram.png)

# %% [markdown]
# Handling Outliers
#
# 1. Replacing outliers with mean, median, mode
# 2. Trimming the outliers data
# 3. Lower and upper capping - capping the lower and upper limits of data and replace the outliers with lower or upper cap
# 4. Zero capping - some parameters which cannot be zero can be replaced by zero and capped

# %% [markdown]
# ### Outlier detection:
# #### Box plot and interquartile range

# %%
import seaborn as sns
plt.figure(figsize = (12,2))
sns.boxplot(x = "Passengers", data=data, whis=1)
# Out:
# <Axes: xlabel='Passengers'>

# %% [markdown]
# #### Histogram:

# %%
plt.figure(figsize=(12,5))
plt.hist("Passengers", data=data)
plt.show()

# %% [markdown]
# **No outliers are found in this data**

# %% [markdown]
# ## Time series decomposition:

# %% [markdown]
# #### additive seasonal decomposition

# %% [markdown]
# **Additive Decomposition**
#
# When the magnitude of the seasonal pattern in the data does not directly correlate with the value of the series, the additive seasonal decomposition may be a better choice to split the time series so that the residual does not have any pattern. This means, that for every seasonal pattern in the time series, the distance between the peaks and the troughs remains the same. Check the below graph for the same.
#
#
#
# Imagine that you are viewing a time series data of rainfall in a city where there is no difference in the average rainfall received during the last 10 years. In this case, since the average rainfall is the same during the 10 years, the seasonal peaks will almost remain the same height and thus we can use additive decomposition over this data. Additive decomposed time series have a linear variation in the trend.

# %%
# %pip install statsmodels
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize']=12,10
decomposition = sm.tsa.seasonal_decompose(data.Passengers, model='additive') #tsa here is time series analysis
fig = decomposition.plot()
plt.show()

# %% [markdown]
# #### Multiplicative seasonal decomposition

# %% [markdown]
# **Multiplicative Decomposition**
#
# When the magnitude of the seasonal pattern in the data increases with an increase in data values and decreases with a decrease in the data values, the multiplicative seasonal decomposition may be a better choice. This means, that for every seasonal pattern in the time series, the distance between the peaks and the troughs keeps increasing. Check the below graph for the same.
#
#
#
# Imagine that you are viewing a time series data of rainfall in a city where now, there is a difference in the average rainfall received during the last 10 years and this keeps increasing every year. In this case, since the average rainfall is increasing during the 10 years, the seasonal peaks will also now keep increasing or the distance between the troughs and the peaks will increase as you progress through the time-series. Multiplicative decomposed time series have a non-linear variation in the trend.

# %%
decomposition = sm.tsa.seasonal_decompose(data.Passengers, model="Multiplicative")
decomposition.plot()
plt.show()

# %% [markdown]
# **NOTE**
#
# the multiplicative seasonal decomposition is used as the trend in the data is slightly non-linear. This is because the magnitude of the seasonal pattern in the data increases as thus additive decompsition will not be able to capture the non-linearity.

# %% [markdown]
# ## Time series Methods:

# %% [markdown]
# #### Naive Method:
# Forecast = Last month’s sales (represented by the green line in the picture below, orange line represents the actual test data)
#
# ![naive_method.png](attachment:naive_method.png)
#
# * useful for Stock market forecasting
# * seasonal naive method: for example, to forecast the sales in january of next year, we can use january data from previous 3 years as sales in january will reach more or less the same. this is seasonal naive method
#
# **NOTE:**
# this is easily effected by the noise in the time series data as the last point in the data changes changes and the forecast adjusts itself every single time!

# %% [markdown]
# #### Simple average method:
# Forecast = Average of all past months’ sales
#
# ![simple_avg_method.png](attachment:simple_avg_method.png)
#
# the green line in the above image is the interpolated trend which neither captures the trend nor the seasonality of the data.
#
# there is another method called **drift method** where a regression line is fit between first point in the data and the last point in the data and extrapolates it to the future. although this method doesn't capture the seasonality of the data, it surely captures the trend to some extent and is better than the simple average line which is no way near as predictive as the data before!

# %% [markdown]
# ## Build and evaluate time series forecast model

# %% [markdown]
# ### Split the time series data into training and test sets

# %%
train_len=120
train = data[0:train_len]
test = data[train_len:]

# %% [markdown]
# ### Naive method of forecasting

# %%
y_hat_naive = test.copy()
y_hat_naive['naive_forecast'] = train['Passengers'][train_len-1]

# %% [markdown]
# ##### Plot train, test and forecast:

# %%
plt.figure(figsize = (12,4))
plt.plot(train['Passengers'], label = 'Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_naive['naive_forecast'], label = 'Naive forecast')
plt.legend(loc='best')
plt.title('Naive forecast method')
plt.show()

# %% [markdown]
# ### Simple average method

# %%
y_hat_avg = test.copy()
y_hat_avg['avg_forecast'] = train['Passengers'].mean()

# %% [markdown]
# ##### plotting train, test and forecast

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_avg['avg_forecast'], label='simple average forecast')
plt.legend(loc='best')
plt.title('Simple average forecast method')
plt.show()

# %% [markdown]
# **Error Measures:**

# %% [markdown]
# _**1.Mean forecast error:**_ In this naive method, you simply subtract the actual values of the dependent variable, i.e., 'y' with the forecasted values of 'y'. This can be represented using the equation below.
#
# ![MFA.png](attachment:MFA.png)

# %% [markdown]
# _**2. Mean Absolute Error:**_ Since MFE might cancel out a lot of overestimated and underestimated forecasts, hence measuring the mean absolute error or MAE makes more sense as in this method, you take the absolute values of the difference between the actual and forecasted values.
#
# ![MAE.png](attachment:MAE.png)

# %% [markdown]
# _**3. Mean Absolute Percentage Error:**_ The problem with MAE is that even if you get an error value, you have nothing to compare it against. For example, if the MAE that you get is 1.5, you cannot tell just on the basis of this number whether you have made a good forecast or not. If the actual values are in single digits, this error of 1.5 is obviously high but if the actual values are, say in the order of thousands, an error of 1.5 indicates a good forecast. So in order to capture how the forecast is doing based upon the actual values, you evaluate mean absolute error where you take the mean absolute error (MAE) as the percentage of the actual values of 'y'.
#
# ![MAPE.png](attachment:MAPE.png)

# %% [markdown]
# _**4. Mean Squared Error:**_ The idea behind mean squared error is the same as mean absolute error, i.e., you want to capture the absolute deviations so that the negative and positive deviations do not cancel each other out. In order to achieve this, you simply square the error values, sum them up and take their average. This is known as mean squared error or MSE which can be represented using the equation below.
#
# ![MSE.png](attachment:MSE.png)

# %% [markdown]
# _**5. Root Mean Squared Error:**_ Since the error term you get from MSE is not in the same dimension as the target variable 'y' (it is squared), you deploy a metric known as RMSE wherein you take the square root of the MSE value obtained.
#
# ![RMSE.png](attachment:RMSE.png)

# %% [markdown]
# #### Calculating MAPE and RMSE for our Naive forecast

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_naive['naive_forecast'])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_naive['naive_forecast'])/test['Passengers'])*100,2)

# %%
results = pd.DataFrame({'Method':['Naive Method'], 'MAPE':[mape], 'RMSE':[rmse]})
results = results[['Method','MAPE','RMSE']]
results
# Out:
#          Method   MAPE    RMSE
# 0  Naive Method  23.63  137.51

# %% [markdown]
# #### Calcuating RMSE and MAPE for simple average forecast

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_avg['avg_forecast'])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_avg['avg_forecast'])/test['Passengers'])*100,2)

tempresults = pd.DataFrame({'Method':['Simple Average method'], 'RMSE':[rmse], 'MAPE':[mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                   Method   MAPE    RMSE
# 0           Naive Method  23.63  137.51
# 0  Simple Average method  44.28  219.69

# %% [markdown]
# #### Performance evaluation of the model:
# the norm of splitting the data into 80% training data and 20% testing data cannot be applied in time series as the data from a future date cannot be used to test the model built on past data.
#
# there are two types of separation of data for performance evaluation for the model
# 1. Cross validation one-step:
# 2. Cross validation multi-step:

# %% [markdown]
# **Cross Validation one-step:**
# The testing set is just one step ahead to the training set. So suppose out of 15 data points, you decided to keep the first 10 of them as 'train' and the next 5 of them as 'test'. Now, the data points in the test set will be taken one-by-one starting from the left since you need all the previous values to predict the future values. So firstly, you take the 11th point to be the test set. Once this value is successfully forecasted, you move on to the 12th point which is now your new test point and so on until you forecast for all the 5 points. This idea is represented in the image below. Here the blue squares represent the train data, the yellow squares represent the test data, and the purple ones are the future values for which the initial test points need to be predicted first. In the image below, you have 7 test data points, hence it takes 7 iterations (or forecasts) to fully predict the test set.
#
# ![one-stepvalidation.jpg](attachment:one-stepvalidation.jpg)

# %% [markdown]
# **Cross validation multi-step:** This is the same as one-step validation, the only difference being that you do not consider a few points to the immediate right of the last training datapoint but rather skip a few of these points to make forecasts well into the future. This can be seen in the image below.
#
# ![multi-stepvalidation.jpg](attachment:multi-stepvalidation.jpg)

# %% [markdown]
# #### Simple Moving average - 12 month window

# %%
y_hat_sma = data.copy() #we are using sma with entire data and not only with test data like in case of naive and average methods as we want to see how this model behaves with entire data.
ma_window = 12 # moving average window
y_hat_sma['sma_forecast'] = data['Passengers'].rolling(ma_window).mean() #rolling(ma_window).mean() will calculate the moving average
y_hat_sma['sma_forecast'][train_len:] = y_hat_sma['sma_forecast'][train_len-1]

# %% [markdown]
# `y_hat_sma['sma_forecast'][train_len:] = y_hat_sma['sma_forecast'][train_len-1]`
#
# since we don't have any data before the starting month of 1959 where our test data starts, we need to pull the forecast of december 1958 into january of 1959 and then continue the forecast from there. the above line of code is an adjustment for that.

# %% [markdown]
# #### Plot train, test and forecast data

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_sma['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title("Simple Moving Average - 12 month window")
plt.show()

# %% [markdown]
# #### Calculate the RMSE and MAPE

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_sma['sma_forecast'][train_len:])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_sma['sma_forecast'][train_len:])/test['Passengers'])*100,2)
tempresults = pd.DataFrame({'Method':['Simple Moving Average'], 'RMSE':[rmse], 'MAPE':[mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                   Method   MAPE    RMSE
# 0           Naive Method  23.63  137.51
# 0  Simple Average method  44.28  219.69
# 0  Simple Moving Average  15.54  103.33

# %% [markdown]
# #### Simple Moving Average - 6 month window

# %%
# we are using sma with entire data and not only with test data like in case of naive and average methods as we want to see how this model behaves with entire data.
y_hat_sma_6m = data.copy()
ma_window = 6  # moving average window
y_hat_sma_6m['sma_forecast'] = data['Passengers'].rolling(ma_window).mean()
# rolling(ma_window).mean() will calculate the moving average
y_hat_sma_6m['sma_forecast'][train_len:] = y_hat_sma_6m['sma_forecast'][train_len-1]

# %% [markdown]
# #### plot train, test and forecast

# %%
plt.figure(figsize=(12, 4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_sma_6m['sma_forecast'], label='6 month - Simple moving average forecast')
plt.legend(loc='best')
plt.title("Simple Moving Average - 6 month window")
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_sma_6m['sma_forecast'][train_len:])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_sma_6m['sma_forecast'][train_len:])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame({'Method': ['Simple Moving Average - 6 months'], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64

# %% [markdown]
# #### Simple moving average - 3 month

# %%
y_hat_sma_3m = data.copy()
ma_window = 3
y_hat_sma_3m['sma_forecast'] = data['Passengers'].rolling(ma_window).mean()
y_hat_sma_3m['sma_forecast'][train_len:] = y_hat_sma_3m['sma_forecast'][train_len-1]

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_sma_3m['sma_forecast'], label="3 month Simple moving average")
plt.legend(loc='best')
plt.title("Simple Moving average - 3 month window")
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_sma_3m['sma_forecast'][train_len:])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_sma_3m['sma_forecast'][train_len:])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame({'Method': ['Simple Moving Average - 3 months'], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64
# 0  Simple Moving Average - 3 months  24.01  138.91

# %% [markdown]
# **NOTE:**
# the smaller the window size becomes, the more noise it will start capturing in the data and the more inconsistent will be the predictions

# %% [markdown]
# ## WEIGHTED MOVING AVERAGE:

# %% [markdown]
# Unlike the simple moving average where the data points are all given same weightage as shown in the below formula:
# ![SIMPLE_MOVING_AVG_FORMULA.png](attachment:SIMPLE_MOVING_AVG_FORMULA.png)

# %% [markdown]
# a weighted moving average gives higher weightage to the most recent data and lower weightage to the older data as shown in the formula below
# ![weighted moving average formula.png](<attachment:weighted moving average formula.png>)

# %% [markdown]
# The weighted moving average can be understood as the moving average where the immediate previous data will largely decide the future of the data forecast rather than the past data.
# ![WEIGHTED MOVING AVG.png](<attachment:WEIGHTED MOVING AVG.png>)

# %% [markdown]
# ## Simple Exponential Smoothing:

# %% [markdown]
# from now on we try to capture all the components of time-series data. **Simple exponential smoothing** will capture the **level** component of Time series data.

# %% [markdown]
# Simple exponential smoothing can be represented mathematically as:
# ![simple exponential smoothing formula.png](<attachment:simple exponential smoothing formula.png>)
#
# where 𝛼 is the level smoothing parameter

# %% [markdown]
# ![simpleexponentialsmoothingexp.png](attachment:simpleexponentialsmoothingexp.png)

# %% [markdown]
# α>α(1−α)>α(1−α)^2...

# %% [markdown]
# levels in simple exponential smoothing:
# ![levels-SES.png](attachment:levels-SES.png)

# %% [markdown]
# and the final forecast equation in simple exponential smoothing after substituting the above level equations wil come out as:
# ![SES-forecast eqn.png](<attachment:SES-forecast eqn.png>)

# %% [markdown]
# where the weights vary as:
# ![weights-SES.png](attachment:weights-SES.png)

# %% [markdown]
# the weights that we are assigning is following an exponential decay as we proceed to the past data.
#
# Here we are only looking at level component and hence it is termed as **simple exponential smoothing**

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
model = SimpleExpSmoothing(train['Passengers'])
model_fit = model.fit(smoothing_level=0.2, optimized=False) # smoothing_level is alpha discussed above. it is the weight assigned to the last availble data.
# optimized=True will try to automatically fix the smoothing_level by itself without considering the suggested smoothing_level.
model_fit.params
y_hat_ses = test.copy()
y_hat_ses['SES forecast'] = model_fit.forecast(24) # here 24 is the test period that we are considering for this forecast
# Out:
# /opt/homebrew/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
### Plot train, test and forecast
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_ses['SES forecast'], label = 'Simple exponential smoothing forecast')
plt.title('Simple exponential smoothing method')
plt.legend(loc='best')
plt.show()

# %%
### calculation of RMSE and MAPE:
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_hat_ses['SES forecast'])).round(2)
mape = np.round(np.mean(np.abs(test['Passengers']-y_hat_ses['SES forecast'])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame({'Method': ['Simple exponential smoothing'], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64
# 0  Simple Moving Average - 3 months  24.01  138.91
# 0      Simple exponential smoothing  16.49  107.65

# %% [markdown]
# ## Holt's Smoothing

# %% [markdown]
# Holt's smoothing can capture both level and trend of the time series data. the base equation of Holt's smoothing is
#
# ![Holts smoothing base eqn.png](<attachment:Holts smoothing base eqn.png>)

# %% [markdown]
# where l(t) is the level component and b(t) is the trend.
# the level and trend for a time period t can be calculated as follows:
#
# ![trend eqn - holt's.png](<attachment:trend eqn - holt's.png>)

# %% [markdown]
# and the level equation for the time period t is given by:
# ![level eqn - Holt's.png](<attachment:level eqn - Holt's.png>)

# %% [markdown]
# where β is trend smoothing character where as 𝛼 is the level smoothing character that we learned in simple exponential smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
model = ExponentialSmoothing(np.asarray(train['Passengers']), seasonal_periods=12, trend='additive', seasonal=None)
model_fit = model.fit(smoothing_level=0.2, smoothing_slope=0.01, optimized=False)
print(model_fit.params)
y_hat_holt = test.copy()
y_hat_holt['hole_forecast'] = model_fit.forecast(24)
# Out:
# {'smoothing_level': 0.2, 'smoothing_trend': 0.01, 'smoothing_seasonal': None, 'damping_trend': nan, 'initial_level': 118.46666666666661, 'initial_trend': 2.060606060606076, 'initial_seasons': array([], dtype=float64), 'use_boxcox': False, 'lamda': None, 'remove_bias': False}

# %% [markdown]
# **NOTE:** the reason to use additive trend in the above model building line is because the earlier decomposition analysis has shown that the data in our case has a linear trend.
#
# 1. When the data follows a linear trend, we use additive trend.
# 2. when the data follows a cubic or exponential trend, then multiplicative trend is used

# %% [markdown]
# ### plot train, test and forecast

# %%
plt.figure(figsize=(12,4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_holt['hole_forecast'], label = 'Holt\'s exponential smoothing')
plt.title("Holt's exponential smoothing")
plt.legend(loc ='best')
plt.show()

# %% [markdown]
# #### RMSE and MAPE

# %%
rmse = np.sqrt(mean_squared_error(
    test['Passengers'], y_hat_holt['hole_forecast'])).round(2)
mape = np.round(np.mean(
    np.abs(test['Passengers']-y_hat_holt['hole_forecast'])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame(
    {'Method': ['Simple exponential smoothing'], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64
# 0  Simple Moving Average - 3 months  24.01  138.91
# 0      Simple exponential smoothing  16.49  107.65
# 0      Simple exponential smoothing  11.39   80.91

# %% [markdown]
# ## Holt-Winter's exponential smoothing:
# it also captures the seasonality as well. so it'll all the 3 components.
# it is driven by the equation:
# ![holt-winter eqn.png](<attachment:holt-winter eqn.png>)

# %% [markdown]
# where the last term is the seasonality component.
#
# here 'm' in the subscript is the number of time periods in each season.
#
# Two methods of modelling the seasonal component
#
# 1. **Additive Method** : we have average sales and we add or substract by a constant values to capture the sales in a particular season. It can be used when seasonality is not a function of level.
#
# 2. **Multiplicative Method**: if in the same example, instead of adding a value, if we mutiply by a constant multiplication factor (can be a percentage or ratio), it's multiplicative method. this is used when with the increase in average, if the distance between crest and trough (ie., the distance from avg line to peak or valley) is increasing, then we can use multiplicative model.

# %% [markdown]
# The seasonality is calculated as
# ![s(t) formula.png](<attachment:s(t) formula.png>)

# %% [markdown]
# **NOTE**: the term
# ![seasonal_effect.png](attachment:seasonal_effect.png)
# is the best guess of the seasonal component of the recent observation that is obtained after subtracting the level and the trend components from yt
#
# The weight of γ is assigned to this component, whereas 1-γ is the weight assigned to the seasonal component of the recent observations.
#
# here γ is the seasonal smoothing parameter
#
# 0 < γ < 1

# %% [markdown]
# the trend b(t) and level l(t) are calculated as
#
# ![trend_eqn.png](attachment:trend_eqn.png)

# %% [markdown]
# ![level_eqn.png](attachment:level_eqn.png)
#
# **NOTE**: in this equation we separate S(t-m) from y(t) to deseasonalize the y(t) term in order to capture the level component

# %% [markdown]
# ### HOLT-WINTER'S Additive method with Trand and Seasonality:

# %%
y_hat_hwa = test.copy()
model = ExponentialSmoothing(np.asarray(train['Passengers']), seasonal_periods=12, trend='add', seasonal='add')
model_fit = model.fit(optimized=True)
print(model_fit.params)
y_hat_hwa['hwa forecast'] = model_fit.forecast(24)
# Out:
# {'smoothing_level': 0.23610576031773078, 'smoothing_trend': 3.119657986294043e-11, 'smoothing_seasonal': 0.7638942395353835, 'damping_trend': nan, 'initial_level': 119.13291325695651, 'initial_trend': 2.276496362305155, 'initial_seasons': array([ -9.42215472,  -3.89155428,   8.62946377,   3.53865062,
#         -5.15883538,   8.98470398,  21.24804749,  19.32981812,
#          5.24155657, -13.60714338, -28.29013586, -12.1350989 ]), 'use_boxcox': False, 'lamda': None, 'remove_bias': False}

# %% [markdown]
# #### Plot train, test and forecast data:

# %%
plt.figure(figsize=(12, 4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_hwa['hwa forecast'], label='Holt-Winter\'s exponential smoothing - ')
plt.title("Holt-Winter's exponential smoothing")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### RMSE and MAPE values:

# %%
rmse = np.sqrt(mean_squared_error(
    test['Passengers'], y_hat_hwa['hwa forecast'])).round(2)
mape = np.round(np.mean(
    np.abs(test['Passengers']-y_hat_hwa['hwa forecast'])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame(
    {'Method': ['Holt-winter\'s additive '], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64
# 0  Simple Moving Average - 3 months  24.01  138.91
# 0      Simple exponential smoothing  16.49  107.65
# 0      Simple exponential smoothing  11.39   80.91
# 0      Simple exponential smoothing   6.72   35.87
# 0           Holt-winter's additive    6.72   35.87

# %% [markdown]
# #### HOLT-WINTER's Multiplicative method with trend and Seasonality

# %%
y_hat_hum = test.copy()
model = ExponentialSmoothing(np.asarray(train['Passengers']), seasonal_periods=12, trend='add', seasonal='add')
model_fit = model.fit(optimized=True)
print(model_fit.params)
y_hat_hum['hwa forecast'] = model_fit.forecast(24)
# Out:
# {'smoothing_level': 0.23610576031773078, 'smoothing_trend': 3.119657986294043e-11, 'smoothing_seasonal': 0.7638942395353835, 'damping_trend': nan, 'initial_level': 119.13291325695651, 'initial_trend': 2.276496362305155, 'initial_seasons': array([ -9.42215472,  -3.89155428,   8.62946377,   3.53865062,
#         -5.15883538,   8.98470398,  21.24804749,  19.32981812,
#          5.24155657, -13.60714338, -28.29013586, -12.1350989 ]), 'use_boxcox': False, 'lamda': None, 'remove_bias': False}

# %% [markdown]
# #### Plot the Train, test and Forecast data

# %%
plt.figure(figsize=(12, 4))
plt.plot(train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_hat_hum['hwa forecast'],
         label='Holt-Winter\'s exponential smoothing - Multiplicative')
plt.title("Holt-Winter's exponential smoothing - Multiplicative")
plt.legend(loc='best')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(
    test['Passengers'], y_hat_hum['hwa forecast'])).round(2)
mape = np.round(np.mean(
    np.abs(test['Passengers']-y_hat_hum['hwa forecast'])/test['Passengers'])*100, 2)
tempresults = pd.DataFrame(
    {'Method': ['Holt-Winter\'s multiplicative'], 'RMSE': [rmse], 'MAPE': [mape]})
results = pd.concat([results, tempresults])
results
# Out:
#                              Method   MAPE    RMSE
# 0                      Naive Method  23.63  137.51
# 0             Simple Average method  44.28  219.69
# 0             Simple Moving Average  15.54  103.33
# 0  Simple Moving Average - 6 months  12.97   90.64
# 0  Simple Moving Average - 3 months  24.01  138.91
# 0      Simple exponential smoothing  16.49  107.65
# 0      Simple exponential smoothing  11.39   80.91
# 0      Simple exponential smoothing   6.72   35.87
# 0           Holt-winter's additive    6.72   35.87
# 0      Holt-Winter's multiplicative   6.72   35.87
